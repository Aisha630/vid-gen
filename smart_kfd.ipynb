# %%
import KeyFrameDetector.key_frame_detector as kfd

source = "/root/VideoReconstruction/input/lamb.mp4"
dest = "keyframes"
bucket_size_in_frames= 60
threshold = 0.3
output_dir = "/root/VideoReconstruction/outputs/bucketedkeyframes/lambshery"
minimum_frames_in_between = 24
maximum_frames_in_between = 30

kfd.smartKeyframeDetection(
    source,
    dest,
    bucket_size_in_frames,
    threshold,
    output_dir,
    minimum_frames_in_between,
    maximum_frames_in_between
)
# Out:
# Net difference in bucket 0 is  87108382
# Net difference in bucket 1 is  99323238
# Net difference in bucket 2 is  96616149
# Net difference in bucket 3 is  104578656
# For /root/VideoReconstruction/input/lamb.mp4, selected 2 frames, and inserted 7 frames.
# [array([[[ 57, 100,  80],
#          [ 57, 100,  80],
#          [ 58, 101,  81],
#          ...,
#          [ 34,  61,  36],
#          [ 35,  62,  37],
#          [ 35,  62,  37]],
#
#         [[ 60, 103,  83],
#          [ 60, 103,  83],
#          [ 61, 104,  84],
#          ...,
#          [ 34,  61,  36],
#          [ 35,  62,  37],
#          [ 35,  62,  37]],
#
#         [[ 63, 106,  86],
#          [ 63, 106,  86],
#          [ 63, 106,  86],
#          ...,
#          [ 34,  61,  36],
#          [ 35,  62,  37],
#          [ 35,  62,  37]],
#
#         ...,
#
#         [[ 75, 102,  89],
#          [ 75, 102,  89],
#          [ 75, 102,  89],
#          ...,
#          [ 82, 118,  99],
#          [ 82, 120, 101],
#          [ 82, 120, 101]],
#
#         [[ 75, 102,  89],
#          [ 75, 102,  89],
#          [ 75, 102,  89],
#          ...,
#          [ 85, 121, 102],
#          [ 85, 123, 104],
#          [ 86, 124, 105]],
#
#         [[ 75, 102,  89],
#          [ 75, 102,  89],
#          [ 75, 102,  89],
#          ...,
#          [ 85, 121, 102],
#          [ 86, 124, 105],
#          [ 87, 125, 106]]], dtype=uint8),
#  array([[[ 54, 100,  77],
#          [ 54, 100,  77],
#          [ 55, 100,  80],
#          ...,
#          [ 31,  61,  39],
#          [ 31,  61,  39],
#          [ 31,  61,  39]],
#
#         [[ 56, 102,  79],
#          [ 56, 102,  79],
#          [ 56, 101,  81],
#          ...,
#          [ 31,  61,  39],
#          [ 31,  61,  39],
#          [ 31,  61,  39]],
#
#         [[ 59, 105,  82],
#          [ 58, 104,  81],
#          [ 56, 101,  81],
#          ...,
#          [ 31,  61,  39],
#          [ 31,  61,  39],
#          [ 31,  61,  39]],
#
#         ...,
#
#         [[ 82, 105,  97],
#          [ 82, 105,  97],
#          [ 82, 105,  97],
#          ...,
#          [ 73, 104,  86],
#          [ 73, 104,  86],
#          [ 73, 104,  86]],
#
#         [[ 80, 106,  96],
#          [ 80, 106,  96],
#          [ 80, 106,  96],
#          ...,
#          [ 73, 104,  86],
#          [ 73, 104,  86],
#          [ 73, 104,  86]],
#
#         [[ 81, 107,  97],
#          [ 80, 106,  96],
#          [ 81, 107,  97],
#          ...,
#          [ 73, 104,  86],
#          [ 73, 104,  86],
#          [ 73, 104,  86]]], dtype=uint8),
#  array([[[ 69, 109,  90],
#          [ 67, 107,  88],
#          [ 65, 105,  86],
#          ...,
#          [ 33,  64,  39],
#          [ 34,  65,  40],
#          [ 34,  65,  40]],
#
#         [[ 69, 109,  90],
#          [ 67, 107,  88],
#          [ 65, 105,  86],
#          ...,
#          [ 33,  64,  39],
#          [ 33,  64,  39],
#          [ 33,  64,  39]],
#
#         [[ 67, 107,  88],
#          [ 66, 106,  87],
#          [ 64, 104,  85],
#          ...,
#          [ 33,  64,  39],
#          [ 33,  64,  39],
#          [ 33,  64,  39]],
#
#         ...,
#
#         [[ 74,  95,  81],
#          [ 73,  94,  80],
#          [ 70,  89,  75],
#          ...,
#          [ 70, 100,  78],
#          [ 70, 100,  78],
#          [ 70, 100,  78]],
#
#         [[ 71,  95,  80],
#          [ 71,  95,  80],
#          [ 72,  91,  77],
#          ...,
#          [ 74, 104,  82],
#          [ 74, 104,  82],
#          [ 74, 104,  82]],
#
#         [[ 71,  95,  80],
#          [ 71,  95,  80],
#          [ 72,  91,  77],
#          ...,
#          [ 74, 104,  82],
#          [ 74, 104,  82],
#          [ 74, 104,  82]]], dtype=uint8),
#  array([[[ 74, 112,  95],
#          [ 73, 111,  94],
#          [ 73, 111,  94],
#          ...,
#          [ 34,  64,  37],
#          [ 34,  64,  37],
#          [ 35,  65,  38]],
#
#         [[ 74, 112,  95],
#          [ 74, 112,  95],
#          [ 74, 112,  95],
#          ...,
#          [ 34,  64,  37],
#          [ 34,  64,  37],
#          [ 35,  65,  38]],
#
#         [[ 75, 113,  96],
#          [ 75, 113,  96],
#          [ 75, 113,  96],
#          ...,
#          [ 34,  64,  37],
#          [ 34,  64,  37],
#          [ 35,  65,  38]],
#
#         ...,
#
#         [[ 69,  88,  72],
#          [ 69,  88,  72],
#          [ 68,  87,  71],
#          ...,
#          [ 71, 107,  95],
#          [ 71, 107,  95],
#          [ 71, 107,  95]],
#
#         [[ 69,  88,  72],
#          [ 69,  88,  72],
#          [ 68,  87,  71],
#          ...,
#          [ 71, 107,  95],
#          [ 71, 107,  95],
#          [ 71, 107,  95]],
#
#         [[ 69,  88,  72],
#          [ 69,  88,  72],
#          [ 68,  87,  71],
#          ...,
#          [ 71, 107,  95],
#          [ 71, 107,  95],
#          [ 71, 107,  95]]], dtype=uint8),
#  array([[[ 87, 123, 111],
#          [ 87, 123, 111],
#          [ 87, 123, 111],
#          ...,
#          [ 34,  62,  40],
#          [ 34,  62,  40],
#          [ 34,  62,  40]],
#
#         [[ 87, 123, 111],
#          [ 87, 123, 111],
#          [ 87, 123, 111],
#          ...,
#          [ 34,  62,  40],
#          [ 34,  62,  40],
#          [ 34,  62,  40]],
#
#         [[ 87, 124, 109],
#          [ 87, 124, 109],
#          [ 87, 124, 109],
#          ...,
#          [ 34,  62,  40],
#          [ 34,  62,  40],
#          [ 34,  62,  40]],
#
#         ...,
#
#         [[ 67,  88,  74],
#          [ 67,  88,  74],
#          [ 67,  88,  74],
#          ...,
#          [ 65,  96,  71],
#          [ 65,  96,  71],
#          [ 65,  96,  71]],
#
#         [[ 66,  87,  73],
#          [ 66,  87,  73],
#          [ 66,  87,  73],
#          ...,
#          [ 67,  98,  73],
#          [ 67,  98,  73],
#          [ 67,  98,  73]],
#
#         [[ 66,  87,  73],
#          [ 66,  87,  73],
#          [ 66,  87,  73],
#          ...,
#          [ 68,  99,  74],
#          [ 68,  99,  74],
#          [ 68,  99,  74]]], dtype=uint8),
#  array([[[ 95, 129, 117],
#          [ 94, 128, 116],
#          [ 94, 128, 116],
#          ...,
#          [ 29,  61,  34],
#          [ 29,  61,  34],
#          [ 29,  61,  34]],
#
#         [[ 95, 129, 117],
#          [ 94, 128, 116],
#          [ 94, 128, 116],
#          ...,
#          [ 29,  61,  34],
#          [ 29,  61,  34],
#          [ 29,  61,  34]],
#
#         [[ 95, 129, 117],
#          [ 94, 128, 116],
#          [ 94, 128, 116],
#          ...,
#          [ 29,  61,  34],
#          [ 29,  61,  34],
#          [ 29,  61,  34]],
#
#         ...,
#
#         [[ 69,  88,  74],
#          [ 69,  88,  74],
#          [ 69,  88,  74],
#          ...,
#          [ 78, 114, 107],
#          [ 78, 114, 107],
#          [ 78, 114, 107]],
#
#         [[ 69,  88,  74],
#          [ 69,  88,  74],
#          [ 69,  88,  74],
#          ...,
#          [ 78, 114, 107],
#          [ 78, 114, 107],
#          [ 78, 114, 107]],
#
#         [[ 69,  88,  74],
#          [ 69,  88,  74],
#          [ 69,  88,  74],
#          ...,
#          [ 78, 114, 107],
#          [ 78, 114, 107],
#          [ 78, 114, 107]]], dtype=uint8),
#  array([[[ 71, 119, 105],
#          [ 71, 119, 105],
#          [ 71, 119, 105],
#          ...,
#          [ 28,  57,  32],
#          [ 28,  57,  32],
#          [ 28,  57,  32]],
#
#         [[ 70, 118, 104],
#          [ 71, 119, 105],
#          [ 71, 119, 105],
#          ...,
#          [ 28,  57,  32],
#          [ 28,  57,  32],
#          [ 28,  57,  32]],
#
#         [[ 72, 118, 104],
#          [ 72, 118, 104],
#          [ 73, 119, 105],
#          ...,
#          [ 28,  57,  32],
#          [ 28,  57,  32],
#          [ 28,  57,  32]],
#
#         ...,
#
#         [[ 74,  92,  85],
#          [ 72,  90,  83],
#          [ 73,  90,  81],
#          ...,
#          [ 70, 102,  81],
#          [ 70, 102,  81],
#          [ 70, 102,  81]],
#
#         [[ 74,  92,  85],
#          [ 72,  90,  83],
#          [ 73,  90,  81],
#          ...,
#          [ 70, 102,  81],
#          [ 70, 102,  81],
#          [ 70, 102,  81]],
#
#         [[ 74,  92,  85],
#          [ 72,  90,  83],
#          [ 73,  90,  81],
#          ...,
#          [ 71, 103,  82],
#          [ 71, 103,  82],
#          [ 71, 103,  82]]], dtype=uint8),
#  array([[[ 68, 115,  90],
#          [ 68, 115,  90],
#          [ 70, 114,  91],
#          ...,
#          [ 34,  63,  38],
#          [ 34,  63,  38],
#          [ 34,  63,  38]],
#
#         [[ 68, 115,  90],
#          [ 68, 115,  90],
#          [ 70, 114,  91],
#          ...,
#          [ 34,  63,  38],
#          [ 34,  63,  38],
#          [ 34,  63,  38]],
#
#         [[ 69, 113,  90],
#          [ 69, 113,  90],
#          [ 69, 112,  92],
#          ...,
#          [ 34,  63,  38],
#          [ 34,  63,  38],
#          [ 34,  63,  38]],
#
#         ...,
#
#         [[ 77,  98,  90],
#          [ 77,  98,  90],
#          [ 74,  95,  87],
#          ...,
#          [ 68, 101,  83],
#          [ 68, 101,  83],
#          [ 68, 101,  83]],
#
#         [[ 76,  97,  89],
#          [ 74,  95,  87],
#          [ 74,  95,  87],
#          ...,
#          [ 66,  99,  81],
#          [ 66,  99,  81],
#          [ 66,  99,  81]],
#
#         [[ 74,  95,  87],
#          [ 74,  95,  87],
#          [ 73,  94,  86],
#          ...,
#          [ 66,  99,  81],
#          [ 66,  99,  81],
#          [ 66,  99,  81]]], dtype=uint8),
#  array([[[ 63, 106,  86],
#          [ 62, 105,  85],
#          [ 61, 104,  84],
#          ...,
#          [ 27,  57,  35],
#          [ 27,  57,  35],
#          [ 27,  57,  35]],
#
#         [[ 63, 106,  86],
#          [ 62, 105,  85],
#          [ 61, 104,  84],
#          ...,
#          [ 27,  57,  35],
#          [ 27,  57,  35],
#          [ 27,  57,  35]],
#
#         [[ 64, 104,  85],
#          [ 64, 104,  85],
#          [ 63, 103,  84],
#          ...,
#          [ 27,  57,  35],
#          [ 27,  57,  35],
#          [ 27,  57,  35]],
#
#         ...,
#
#         [[ 65,  93,  78],
#          [ 67,  95,  80],
#          [ 72, 100,  85],
#          ...,
#          [ 75, 107,  93],
#          [ 75, 107,  93],
#          [ 75, 107,  93]],
#
#         [[ 65,  93,  78],
#          [ 68,  96,  81],
#          [ 72, 100,  85],
#          ...,
#          [ 75, 107,  93],
#          [ 75, 107,  93],
#          [ 75, 107,  93]],
#
#         [[ 65,  93,  78],
#          [ 68,  96,  81],
#          [ 72, 100,  85],
#          ...,
#          [ 75, 107,  93],
#          [ 75, 107,  93],
#          [ 75, 107,  93]]], dtype=uint8)]
